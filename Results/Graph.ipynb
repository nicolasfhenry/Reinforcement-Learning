# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set(style="ticks", color_codes=True)
sns.set_context("notebook")


import os
from neuralnets_VBN import NeuralNetwork
from useful_func import *

# %%
def plot_reward(results,name,Batch):
    
    data = []
    data = [[i[0] for i in result['reward'] ] for result in results]
    
    plt.figure(figsize = (8,8))
    for d,n in zip(data,name):
        plt.plot(d,label=n)
    plt.title('Comparison of Methods'+'_' + str(Batch),fontsize=20)
    plt.ylabel('Reward',fontsize=20)
    plt.xlabel('Episode',fontsize=20)
    plt.legend()
    plt.savefig('ComparisonOfMethods'+str(Batch) + '.png')
    plt.show()

# %%
Batch = 1
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')


plot_reward([result1,result2,result3,result4,result5],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness'],Batch)

# %%
Batch = 2
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')


plot_reward([result1,result2,result3,result4,result5],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness'],Batch)

# %%
Batch = 3
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')


plot_reward([result1,result2,result3,result4,result5],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness'],Batch)

# %%
Batch = 4
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')


plot_reward([result1,result2,result3,result4,result5],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness'],Batch)

# %%
Batch = 5
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')
result6 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_noVBN.py')
result7 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_VBN.py')

plot_reward([result1,result2,result3,result4,result5,result6,result7],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness','main_noGS_noVBN.py','main_noGS_VBN.py'],Batch)

# %%
#Fixed Seed
Batch = 6
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')
result6 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_noVBN.py')
result7 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_VBN.py')

plot_reward([result1,result2,result3,result4,result5,result6,result7],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness','noGS_noVBN','noGS_VBN'],Batch)

# %%
#Fixed Seed
Batch = 7
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')
result6 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_noVBN.py')
result7 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_VBN.py')

plot_reward([result1,result2,result3,result4,result5,result6,result7],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness','noGS_noVBN','noGS_VBN'],Batch)

# %%
#Semi Random Seed
Batch = 8
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')
result6 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_noVBN.py')
result7 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_VBN.py')

plot_reward([result1,result2,result3,result4,result5,result6,result7],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness','noGS_noVBN','noGS_VBN'],Batch)

# %%
#Semi Random Seed
Batch = 9
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')
result6 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_noVBN.py')
result7 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_VBN.py')

plot_reward([result1,result2,result3,result4,result5,result6,result7],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness','noGS_noVBN','noGS_VBN'],Batch)

# %%
#Fixed Seed
Batch = 10
result1 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_mirror_noVBN.py')
result2 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_mirror_VBN.py')
result3 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' + 'mainGS_noMirror_VBN.py')
result4 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN.py')
result5 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'mainGS_noVBN_noFitness.py')
result6 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_noVBN.py')
result7 = load_obj('/Acrobots/'+ 'Batch' + str(Batch) + '/' +'main_noGS_VBN.py')

plot_reward([result1,result2,result3,result4,result5,result6,result7],['GS_mirror_noVBN','GS_mirror_VBN','GS_noMirror_VBN','GS_noVBN','GS_noVBN_noFitness','noGS_noVBN','noGS_VBN'],Batch)
